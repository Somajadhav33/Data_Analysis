# %%
import numpy as np

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# %%
print(A)
print(B)
# Out:
# [[1 2]
#  [3 4]]
# [[5 6]
#  [7 8]]

# %%
A * B #Wrong
# Out:
# array([[ 5, 12],
#        [21, 32]])

# %%
A @ B #Right
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
np.dot(A, B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A.T
# Out:
# array([[1, 3],
#        [2, 4]])
